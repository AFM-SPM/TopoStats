# %%
import re
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import numpy.typing as npt
from scipy.ndimage import shift as ndimage_shift
from scipy.signal import correlate2d
from skimage.registration import phase_cross_correlation
from skimage.filters import window
from skimage.transform import warp_polar
from scipy.fft import fft2, fftshift
from skimage.transform import rotate, rescale

from topostats.classes import TopoStats
from topostats.io import LoadScans
from topostats.plottingfuncs import Colormap

colourmap = Colormap()
cmap = colourmap.get_cmap()

VMIN = -3
VMAX = 4

# %%
dir_base = Path("/Users/sylvi/topo_data/kinga-before-after-proteins")
assert dir_base.exists()
dir_data = dir_base / "data" / "before_and_afters"
assert dir_data.exists()
dir_processed_data = dir_base / "output/data/before_and_afters/processed"
assert dir_processed_data.exists()
dir_processed_data_topostats = dir_processed_data / "topostats"
assert dir_processed_data_topostats.exists()
dir_results = dir_base / "results"
dir_results.mkdir(exist_ok=True)

raw_files = list(dir_data.glob("*.spm"))
print(f"found {len(raw_files)} raw files")

# %%
def align_images_phase_correlation(image_1: npt.NDArray, image_2: npt.NDArray, upscale_factor: int = 1) -> npt.NDArray:
    """Align two images using phase correlation."""

    # apply a window to reduce edge effects
    height_1, width_1 = image_1.shape
    height_2, width_2 = image_2.shape
    assert height_1 == height_2 and width_1 == width_2, "images must be the same size"
    # create a 2d hanning window that smoothly goes to zero at the edges, remember that the outer function turns the
    # vectors into a matrix with every combination of the two vectors.
    window = np.outer(np.hanning(height_1), np.hanning(width_1)).astype(np.float64)
    # ensure that the images fade to zero at the edges to allow the FFT to work properly without introducing artefacts
    # at the edges.
    reference_image = image_1 * window
    moving_image = image_2 * window

    # upsample_factor is used to increase the resolution of
    # the shift, eg by 10 times, so the shift resolution is 1/10th of a pixel.
    # shift is the number of pixels to shift the image by
    # error is the RMS error between the aligned images
    # diff_phase is the global phase difference between the
    # images (should be close to 0 if images non-negative)
    shift, error, diff_phase = phase_cross_correlation(
        reference_image=reference_image, moving_image=moving_image, upsample_factor=upscale_factor
    )

    # order=1: use linaer interpolation as opposed to polynomial.
    # mode="constant": fill the edges with a constant value, 0
    aligned_image = ndimage_shift(image_2, shift=shift, order=1, mode="constant", cval=0)
    return aligned_image


def align_images_rotation(image_1: npt.NDArray, image_2: npt.NDArray) -> npt.NDArray:
    """Align two images that are rotated with respect to each other."""
    pass


def fft_image(image: npt.NDArray) -> npt.NDArray:
    """Calculate the FFT of an image"""
    image_windowed = image * window("hann", image.shape)
    image_fft = fft2(image_windowed)
    # shift the zero frequency component to the center of the spectrum
    image_fft_shifted = fftshift(image_fft)
    return np.abs(image_fft_shifted)

# %%
# get the first pair
pair_index = 3
filename_pre_treatment = dir_processed_data_topostats / f"PAIR{pair_index}_JustDNA.topostats"
filename_post_treatment = dir_processed_data_topostats / f"PAIR{pair_index}_PARP.topostats"
assert filename_pre_treatment.exists()
assert filename_post_treatment.exists()

files = [filename_pre_treatment, filename_post_treatment]
loadscans = LoadScans(files, config={"loading": {"channel": "Height Sensor"}})
loadscans.get_data()
img_dict = loadscans.img_dict
file_pre_treatment: TopoStats = img_dict[filename_pre_treatment.name]
file_post_treatment: TopoStats = img_dict[filename_post_treatment.name]

pre_treatment_image = file_pre_treatment.image
post_treatment_image = file_post_treatment.image

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(pre_treatment_image, cmap=cmap, vmin=VMIN, vmax=VMAX)
ax[0].set_title("pre-treatment")
ax[1].imshow(post_treatment_image, cmap=cmap, vmin=VMIN, vmax=VMAX)
ax[1].set_title("post-treatment")
plt.suptitle(f"PAIR{pair_index}")
plt.show()

# subtract the pre-treatment from post-treatment
difference_image = post_treatment_image - pre_treatment_image
plt.imshow(difference_image, cmap="gray", vmin=VMIN, vmax=VMAX)
plt.title(f"pair {pair_index} difference (post - pre)")
plt.colorbar(label="height difference (nm)")
plt.show()

# align the images
aligned_post_treatment_image = align_images_phase_correlation(
    pre_treatment_image, post_treatment_image, upscale_factor=10
)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(np.log(np.abs(pre_treatment_image_fft)), cmap="gray")
plt.title("Pre-treatment FFT")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(np.log(np.abs(aligned_post_treatment_image_fft)), cmap="gray")
plt.title("Aligned Post-treatment FFT")
plt.colorbar()
plt.suptitle(f"PAIR{pair_index} FFTs")
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(pre_treatment_image, cmap=cmap, vmin=VMIN, vmax=VMAX)
ax[0].set_title("pre-treatment")
ax[1].imshow(aligned_post_treatment_image, cmap=cmap, vmin=VMIN, vmax=VMAX)
ax[1].set_title("aligned post-treatment")
plt.suptitle(f"PAIR{pair_index}")
plt.show()

# subtract the pre-treatment from aligned post-treatment
aligned_difference_image = aligned_post_treatment_image - pre_treatment_image
plt.imshow(aligned_difference_image, cmap="gray", vmin=VMIN, vmax=VMAX)
plt.title(f"pair {pair_index} aligned difference (post - pre)")
plt.colorbar(label="height difference (nm)")
plt.show()

# now try rotational alignment of the pre-treated and the aligned post-treated images
fft_pre_treatment_image = fft_image(pre_treatment_image)
fft_aligned_post_treatment_image = fft_image(aligned_post_treatment_image)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(np.log(np.abs(fft_pre_treatment_image)), cmap="gray")
plt.title("Pre-treatment FFT")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(np.log(np.abs(fft_aligned_post_treatment_image)), cmap="gray")
plt.title("Aligned Post-treatment FFT")
plt.colorbar()
plt.suptitle(f"PAIR{pair_index} FFTs")
plt.show()

# convert the FFTs to polar coordinates to find the rotation angle
radius = fft_pre_treatment_image.shape[0] // 4
fft_pre_treatment_polar = warp_polar(fft_pre_treatment_image, radius=radius, scaling="log")
fft_aligned_post_treatment_polar = warp_polar(fft_aligned_post_treatment_image, radius=radius, scaling="log")
# only use first half of the polar image since it's symmetric
fft_pre_treatment_polar = fft_pre_treatment_polar[: fft_pre_treatment_polar.shape[1] // 2, :]
fft_aligned_post_treatment_polar = fft_aligned_post_treatment_polar[: fft_aligned_post_treatment_polar.shape[1] // 2, :]


plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(np.log(np.abs(fft_pre_treatment_polar)), cmap="gray")
plt.title("Pre-treatment Polar FFT")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(np.log(np.abs(fft_aligned_post_treatment_polar)), cmap="gray")
plt.title("Aligned Post-treatment Polar FFT")
plt.colorbar()
plt.suptitle(f"PAIR{pair_index} Polar FFTs")
plt.show()


assert fft_pre_treatment_polar.shape == fft_aligned_post_treatment_polar.shape
# do phase correlation on the polar images to find the rotation angle
shifts, error, diff_phase = phase_cross_correlation(
    reference_image=fft_pre_treatment_polar, moving_image=fft_aligned_post_treatment_polar, upsample_factor=10
)
print(f"shifts: {shifts}")
# convert the shift in the polar image to a rotation angle in degrees
# this is done by dividing the shift in the polar image by the number of pixels in the polar image and multiplying
# by 360 since a full rotation corresponds to a shift of the entire polar image

# there are two dimensions to the returned shift, the first is the shift in the angular direction and the second is the
# shift in the radial direction (see skimage's examples to see this is the case)

# calculate the rotation angle in degrees from the shift in the angular direction
shift_angular, shift_radial = shifts
shift_angle = (360 / fft_pre_treatment_polar.shape[0]) * shift_angular
print(f"rotation angle: {shift_angle} degrees")

# calculate the scale factor from the shift in the radial direction
k_log = fft_pre_treatment_polar.shape[1] / np.log(radius)  # no idea, following the example
scale_factor = np.exp(shift_radial / k_log)
print(f"scale factor: {scale_factor}")

# rotate the aligned post-treatment image by the calculated rotation angle and scale factor
centre = (aligned_post_treatment_image.shape[1] // 2, aligned_post_treatment_image.shape[0] // 2)
centre_exploration_range_px = 80
centre_exploration_step_size = 8
best_score = np.inf
best_centre = centre
for x_shift in range(-centre_exploration_range_px, centre_exploration_range_px + 1, centre_exploration_step_size):
    for y_shift in range(-centre_exploration_range_px, centre_exploration_range_px + 1, centre_exploration_step_size):
        shifted_centre = (centre[0] + x_shift, centre[1] + y_shift)
        aligned_post_treatment_image_rotated = rotate(
            aligned_post_treatment_image, -shift_angle, resize=False, mode="constant", cval=0, center=shifted_centre
        )
        aligned_post_treatment_image_rotated_scaled = rescale(
            aligned_post_treatment_image_rotated,
            scale_factor,
            mode="constant",
            cval=0,
            anti_aliasing=False,
        )
        # crop the scaled image to the original size
        center_y, center_x = (
            aligned_post_treatment_image_rotated_scaled.shape[0] // 2,
            aligned_post_treatment_image_rotated_scaled.shape[1] // 2,
        )
        half_height, half_width = pre_treatment_image.shape[0] // 2, pre_treatment_image.shape[1] // 2
        aligned_post_treatment_image_rotated_scaled_cropped = aligned_post_treatment_image_rotated_scaled[
            center_y - half_height : center_y + half_height, center_x - half_width : center_x + half_width
        ]
        score = np.sum((aligned_post_treatment_image_rotated_scaled_cropped - pre_treatment_image) ** 2)
        if score < best_score:
            best_score = score
            best_centre = shifted_centre

print(f"best centre: {best_centre}, best score: {best_score}")

aligned_post_treatment_image_rotated = rotate(
    aligned_post_treatment_image, -shift_angle, resize=False, mode="constant", cval=0, center=best_centre
)
aligned_post_treatment_image_rotated_scaled = rescale(
    aligned_post_treatment_image_rotated, scale_factor, mode="constant", cval=0, anti_aliasing=False
)
# crop the scaled image to the original size
center_y, center_x = (
    aligned_post_treatment_image_rotated_scaled.shape[0] // 2,
    aligned_post_treatment_image_rotated_scaled.shape[1] // 2,
)
half_height, half_width = pre_treatment_image.shape[0] // 2, pre_treatment_image.shape[1] // 2
aligned_post_treatment_image_rotated_scaled_cropped = aligned_post_treatment_image_rotated_scaled[
    center_y - half_height : center_y + half_height, center_x - half_width : center_x + half_width
]
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(pre_treatment_image, cmap=cmap, vmin=VMIN, vmax=VMAX)
plt.title("Pre-treatment")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(aligned_post_treatment_image_rotated_scaled_cropped, cmap=cmap, vmin=VMIN, vmax=VMAX)
plt.title("Aligned, Rotated, and Scaled Post-treatment")
plt.colorbar()
plt.suptitle(f"PAIR{pair_index} Aligned, Rotated, and Scaled Images")
plt.show()

# subtract the pre-treatment from the aligned, rotated, and scaled post-treatment
final_difference_image = aligned_post_treatment_image_rotated_scaled_cropped - pre_treatment_image
plt.imshow(final_difference_image, cmap="gray", vmin=VMIN, vmax=VMAX)
plt.title(f"pair {pair_index} final difference (post - pre)")
plt.colorbar(label="height difference (nm)")
plt.show()
