# %%
from keras.utils import normalize
import os
import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from unet import unet_model
import random
from pathlib import Path
import logging
import itertools

LOGGER = logging.getLogger()
from datetime import datetime

from skimage.morphology import binary_erosion
from skimage.morphology import skeletonize
from skimage.filters import hessian
from skimage.feature import hessian_matrix, hessian_matrix_eigvals
from skimage.morphology import label
from skimage.measure import regionprops
from skimage.color import label2rgb

import tensorflow as tf
from sklearn.model_selection import train_test_split

for key, value in os.environ.items():
    print(f"{key} : {value}")
# Out:
# 2023-10-18 21:25:54.408650: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# CHROME_DESKTOP : code-url-handler.desktop
# DBUS_SESSION_BUS_ADDRESS : unix:path=/run/user/1000/bus
# DEFAULTS_PATH : /usr/share/gconf/pop.default.path
# DESKTOP_SESSION : pop
# DISPLAY : :1
# ELECTRON_NO_ATTACH_CONSOLE : 1
# GDK_BACKEND : x11
# GDMSESSION : pop
# GIO_LAUNCHED_DESKTOP_FILE : /usr/share/applications/gitkraken.desktop
# GIO_LAUNCHED_DESKTOP_FILE_PID : 3708
# GJS_DEBUG_OUTPUT : stderr
# GJS_DEBUG_TOPICS : JS ERROR;JS LOG
# GNOME_DESKTOP_SESSION_ID : this-is-deprecated
# GNOME_SHELL_SESSION_MODE : pop
# GPG_AGENT_INFO : /run/user/1000/gnupg/S.gpg-agent:0:1
# GTK_IM_MODULE : ibus
# GTK_MODULES : gail:atk-bridge
# HOME : /home/sylvia
# INVOCATION_ID : 4efe8b6744ab463087e1902acf6c2bee
# JOURNAL_STREAM : 8:34515
# LANG : en_US.UTF-8
# LOGNAME : sylvia
# MANAGERPID : 2590
# MANDATORY_PATH : /usr/share/gconf/pop.mandatory.path
# ORIGINAL_XDG_CURRENT_DESKTOP : Unity
# PATH : /home/sylvia/anaconda3/envs/car-or-truck-p9/bin:/home/sylvia/anaconda3/condabin:/home/sylvia/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/usr/lib/cuda/bin
# PWD : /home/sylvia
# QT_ACCESSIBILITY : 1
# QT_IM_MODULE : ibus
# SESSION_MANAGER : local/pop-os:@/tmp/.ICE-unix/2782,unix/pop-os:/tmp/.ICE-unix/2782
# SHELL : /bin/bash
# SHLVL : 1
# SSH_AGENT_LAUNCHER : gnome-keyring
# SSH_AUTH_SOCK : /run/user/1000/keyring/ssh
# SYSTEMD_EXEC_PID : 2801
# USER : sylvia
# USERNAME : sylvia
# VSCODE_AMD_ENTRYPOINT : vs/workbench/api/node/extensionHostProcess
# VSCODE_CLI : 1
# VSCODE_CODE_CACHE_PATH : /home/sylvia/.config/Code/CachedData/6c3e3dba23e8fadc360aed75ce363ba185c49794
# VSCODE_CRASH_REPORTER_PROCESS_TYPE : extensionHost
# VSCODE_CWD : /home/sylvia
# VSCODE_HANDLES_UNCAUGHT_ERRORS : true
# VSCODE_IPC_HOOK : /run/user/1000/vscode-a1af13b9-1.81-main.sock
# VSCODE_NLS_CONFIG : {"locale":"en-us","osLocale":"en-us","availableLanguages":{},"_languagePackSupport":true}
# VSCODE_PID : 6223
# WINDOWPATH : 2
# XAUTHORITY : /run/user/1000/gdm/Xauthority
# XDG_CONFIG_DIRS : /etc/xdg/xdg-pop:/etc/xdg
# XDG_CURRENT_DESKTOP : Unity
# XDG_DATA_DIRS : /usr/share/pop:/usr/share/gnome:/home/sylvia/.local/share/flatpak/exports/share:/var/lib/flatpak/exports/share:/usr/local/share/:/usr/share/
# XDG_MENU_PREFIX : gnome-
# XDG_RUNTIME_DIR : /run/user/1000
# XDG_SESSION_CLASS : user
# XDG_SESSION_DESKTOP : pop
# XDG_SESSION_TYPE : x11
# XMODIFIERS : @im=ibus
# ELECTRON_RUN_AS_NODE : 1
# APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL : 1
# VSCODE_L10N_BUNDLE_LOCATION :
# PYTHONUNBUFFERED : 1
# CONDA_EXE : /home/sylvia/anaconda3/bin/conda
# _CE_M :
# CONDA_ROOT : /home/sylvia/anaconda3
# CONDA_PREFIX : /home/sylvia/anaconda3/envs/car-or-truck-p9
# CONDA_PROMPT_MODIFIER : (car-or-truck-p9)
# _CE_CONDA :
# PYTHONIOENCODING : utf-8
# CONDA_SHLVL : 2
# XLA_FLAGS : --xla_gpu_cuda_data_dir=/usr/lib/cuda
# CONDA_PYTHON_EXE : /home/sylvia/anaconda3/bin/python
# LD_LIBRARY_PATH : /home/sylvia/anaconda3/envs/car-or-truck-p9/lib/python3.9/site-packages/cv2/../../lib64::/home/sylvia/anaconda3/envs/car-or-truck-p9/lib/python3.9/site-packages/tensorrt/:/home/sylvia/anaconda3/envs/car-or-truck-p9/lib/python3.9/site-packages/nvidia/cudnn/lib/
# CONDA_DEFAULT_ENV : car-or-truck-p9
# CONDA_PREFIX_1 : /home/sylvia/anaconda3
# _ : /home/sylvia/anaconda3/envs/car-or-truck-p9/bin/python
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING : 1
# PYDEVD_USE_FRAME_EVAL : NO
# TERM : xterm-color
# CLICOLOR : 1
# FORCE_COLOR : 1
# CLICOLOR_FORCE : 1
# PAGER : cat
# GIT_PAGER : cat
# MPLBACKEND : module://matplotlib_inline.backend_inline
# TPU_ML_PLATFORM : Tensorflow
# TF2_BEHAVIOR : 1
# QT_QPA_PLATFORM_PLUGIN_PATH : /home/sylvia/anaconda3/envs/car-or-truck-p9/lib/python3.9/site-packages/cv2/qt/plugins
# QT_QPA_FONTDIR : /home/sylvia/anaconda3/envs/car-or-truck-p9/lib/python3.9/site-packages/cv2/qt/fonts
# KMP_DUPLICATE_LIB_OK : True
# KMP_INIT_AT_FORK : FALSE
# 2023-10-18 21:25:55.921569: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:55.925286: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:55.925442: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:55.925765: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-18 21:25:55.926260: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:55.926385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:55.926492: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.365611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.365763: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.365875: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.365977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21425 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:09:00.0, compute capability: 8.6

# %%
# Ensure that your GPU is working
tf.test.gpu_device_name()
# Out:
# 2023-10-18 21:25:56.745297: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# '/device:GPU:0'
# 2023-10-18 21:25:56.745513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.745662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.745875: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.746033: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-18 21:25:56.746151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 21425 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:09:00.0, compute capability: 8.6

# %%
# Set the random seeds
SEED = 0
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# MacOS
ORIGINAL_IMAGE_DIR = Path("/Users/sylvi/topo_data/hariborings/training_data/on_target_flattened")
MASK_DIR = Path("/Users/sylvi/topo_data/hariborings/training_data/on_target_labelled")

# Linux
ORIGINAL_IMAGE_DIR = Path("/home/sylvia/haribo_data/training_data/on_target_flattened")
MASK_DIR = Path("/home/sylvia/haribo_data/training_data/on_target_labelled")

MODEL_SAVE_DIR = Path("./saved_models")
CHANNELS = 1

BATCH_SIZE = 5

# Get the number of .png images
NUM_IMAGES = len(list(ORIGINAL_IMAGE_DIR.glob("*.png")))
print(f"Number of images: {NUM_IMAGES}")
# Out:
# Number of images: 9

# %%
# An image generator that loads images as they are needed
def image_generator(image_indexes, batch_size=4):
    while True:
        # Select files (paths/indices) for the batch
        batch_image_indexes = np.random.choice(a=image_indexes, size=batch_size)
        batch_input = []
        batch_output = []

        # Load the image and ground truth
        for index in batch_image_indexes:
            # Find the index as the only number in the filename
            # index = re.search(r"\d+", image_path)
            # print(index)
            image = cv2.imread(str(ORIGINAL_IMAGE_DIR / f"image_{index}.png"), 0)
            image = Image.fromarray(image)
            image = image.resize((512, 512))
            image = np.array(image)
            # Normalise the image
            image = image - np.min(image)
            image = image / np.max(image)

            # ground_truth = np.load(MASK_DIR / f"mask_array_{index}.npy")
            ground_truth = cv2.imread(str(MASK_DIR / f"mask_{index}.png"), 0)
            ground_truth = Image.fromarray(ground_truth)
            ground_truth = np.array(ground_truth)
            ground_truth = ground_truth.astype(bool)
            ground_truth = Image.fromarray(ground_truth.astype(np.uint8))
            ground_truth = ground_truth.resize((512, 512))
            ground_truth = np.array(ground_truth).astype(int)

            # Augment the images
            # Flip the images 50% of the time
            if random.choice([0, 1]) == 1:
                image = np.flip(image, axis=1)
                ground_truth = np.flip(ground_truth, axis=1)
            # Rotate the images by either 0, 90, 180, or 270 degrees
            rotation = random.choice([0, 1, 2, 3])
            image = np.rot90(image, rotation)
            ground_truth = np.rot90(ground_truth, rotation)

            batch_input.append(image)
            batch_output.append(ground_truth)

        batch_x = np.array(batch_input).astype(np.float32)
        batch_y = np.array(batch_output).astype(np.float32)

        yield (batch_x, batch_y)

# %%
# Check that the generator is doing the right thing
batch_generator = image_generator([0, 1, 2, 3, 4], batch_size=4)
(batch_x, batch_y) = next(batch_generator)
for image, mask in zip(batch_x, batch_y):
    plt.imshow(image)
    print(f"image shape: {image.shape}")
    print(f"image max: {np.max(image)}")
    print(f"image min: {np.min(image)}")
    plt.show()
    plt.imshow(mask)
    print(f"mask shape: {mask.shape}")
    print(f"mask unique: {np.unique(mask)}")
    plt.show()

    print(f"mask dtype: {mask.dtype}")
# Out:
# image shape: (512, 512)
# image max: 1.0
# image min: 0.0
# mask shape: (512, 512)
# mask unique: [0. 1.]
# mask dtype: float32
# image shape: (512, 512)
# image max: 1.0
# image min: 0.0
# mask shape: (512, 512)
# mask unique: [0. 1.]
# mask dtype: float32
# image shape: (512, 512)
# image max: 1.0
# image min: 0.0
# mask shape: (512, 512)
# mask unique: [0. 1.]
# mask dtype: float32
# image shape: (512, 512)
# image max: 1.0
# image min: 0.0
# mask shape: (512, 512)
# mask unique: [0. 1.]
# mask dtype: float32

# %%
# Split what images are used for training and validation
train_image_indexes, validation_image_indexes = train_test_split(range(0, NUM_IMAGES), test_size=0.2, random_state=SEED)

print(f"Number of training images: {len(train_image_indexes)}")
print(f"Number of validation images: {len(validation_image_indexes)}")

print(f"Training image indexes: {train_image_indexes}")
print(f"Validation image indexes: {validation_image_indexes}")

# Create the generators
train_generator = image_generator(train_image_indexes, batch_size=4)
validation_generator = image_generator(validation_image_indexes, batch_size=4)
# Out:
# Number of training images: 7
# Number of validation images: 2
# Training image indexes: [1, 4, 8, 6, 3, 0, 5]
# Validation image indexes: [7, 2]

# %%
# Get the model
model = unet_model(IMG_HEIGHT=512, IMG_WIDTH=512, IMG_CHANNELS=CHANNELS)
# model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 16  160         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 512, 512, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 256, 256, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 32  9248        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d_1[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 128, 128, 64  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  36928       ['dropout_2[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 32, 32, 256)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 256)  590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_11[0][0]']
#  spose)                         )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_1[0][0]',
#                                 8)                                'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_1[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 128, 128, 64  0           ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_6[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 256, 256, 32  0           ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_7[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 512, 512, 16  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,940,817
# Trainable params: 1,940,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
EPOCHS = 200
history = model.fit(
    train_generator,
    # How many steps (batches of samples) to draw from generator before declaring one epoch finished and starting the next epoch
    steps_per_epoch=NUM_IMAGES // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_generator,
    # How many steps (batches) to yield from validation generator at the end of every epoch
    validation_steps=NUM_IMAGES // BATCH_SIZE,
    verbose=1,
)
# Out:
# Epoch 1/200
# 2023-10-18 21:25:59.065709: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-18 21:25:59.225843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8800
# 2023-10-18 21:25:59.819323: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1/1 [==============================] - 3s 3s/step - loss: 0.9314 - mean_io_u: 0.4968 - val_loss: 0.8848 - val_mean_io_u: 0.4967
# Epoch 2/200
# 1/1 [==============================] - 0s 263ms/step - loss: 0.8171 - mean_io_u: 0.4945 - val_loss: 0.8393 - val_mean_io_u: 0.4961
# Epoch 3/200
# 1/1 [==============================] - 0s 228ms/step - loss: 0.7909 - mean_io_u: 0.4944 - val_loss: 0.8016 - val_mean_io_u: 0.4955
# Epoch 4/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.7949 - mean_io_u: 0.4949 - val_loss: 0.7857 - val_mean_io_u: 0.4961
# Epoch 5/200
# 1/1 [==============================] - 0s 344ms/step - loss: 0.7633 - mean_io_u: 0.4945 - val_loss: 0.7727 - val_mean_io_u: 0.4967
# Epoch 6/200
# 1/1 [==============================] - 0s 218ms/step - loss: 0.7568 - mean_io_u: 0.4961 - val_loss: 0.7438 - val_mean_io_u: 0.4961
# Epoch 7/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.7342 - mean_io_u: 0.4957 - val_loss: 0.7338 - val_mean_io_u: 0.4967
# Epoch 8/200
# 1/1 [==============================] - 0s 330ms/step - loss: 0.7515 - mean_io_u: 0.4968 - val_loss: 0.7082 - val_mean_io_u: 0.4961
# Epoch 9/200
# 1/1 [==============================] - 0s 231ms/step - loss: 0.7149 - mean_io_u: 0.4965 - val_loss: 0.6916 - val_mean_io_u: 0.4955
# Epoch 10/200
# 1/1 [==============================] - 0s 327ms/step - loss: 0.6948 - mean_io_u: 0.4949 - val_loss: 0.6871 - val_mean_io_u: 0.4961
# Epoch 11/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.6988 - mean_io_u: 0.4962 - val_loss: 0.6812 - val_mean_io_u: 0.4967
# Epoch 12/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.6840 - mean_io_u: 0.4948 - val_loss: 0.6689 - val_mean_io_u: 0.4955
# Epoch 13/200
# 1/1 [==============================] - 0s 329ms/step - loss: 0.6792 - mean_io_u: 0.4947 - val_loss: 0.6673 - val_mean_io_u: 0.4967
# Epoch 14/200
# 1/1 [==============================] - 0s 323ms/step - loss: 0.6910 - mean_io_u: 0.4974 - val_loss: 0.6589 - val_mean_io_u: 0.4967
# Epoch 15/200
# 1/1 [==============================] - 0s 331ms/step - loss: 0.6651 - mean_io_u: 0.4957 - val_loss: 0.6523 - val_mean_io_u: 0.4961
# Epoch 16/200
# 1/1 [==============================] - 0s 312ms/step - loss: 0.6585 - mean_io_u: 0.4933 - val_loss: 0.6478 - val_mean_io_u: 0.4961
# Epoch 17/200
# 1/1 [==============================] - 0s 357ms/step - loss: 0.6537 - mean_io_u: 0.4942 - val_loss: 0.6444 - val_mean_io_u: 0.4967
# Epoch 18/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.6535 - mean_io_u: 0.4947 - val_loss: 0.6385 - val_mean_io_u: 0.4955
# Epoch 19/200
# 1/1 [==============================] - 0s 252ms/step - loss: 0.6533 - mean_io_u: 0.4970 - val_loss: 0.6346 - val_mean_io_u: 0.4967
# Epoch 20/200
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6427 - mean_io_u: 0.4955 - val_loss: 0.6300 - val_mean_io_u: 0.4955
# Epoch 21/200
# 1/1 [==============================] - 0s 225ms/step - loss: 0.6404 - mean_io_u: 0.4941 - val_loss: 0.6263 - val_mean_io_u: 0.4961
# Epoch 22/200
# 1/1 [==============================] - 0s 329ms/step - loss: 0.6348 - mean_io_u: 0.4932 - val_loss: 0.6227 - val_mean_io_u: 0.4961
# Epoch 23/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6314 - mean_io_u: 0.4946 - val_loss: 0.6192 - val_mean_io_u: 0.4955
# Epoch 24/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.6301 - mean_io_u: 0.4961 - val_loss: 0.6146 - val_mean_io_u: 0.4967
# Epoch 25/200
# 1/1 [==============================] - 0s 169ms/step - loss: 0.6260 - mean_io_u: 0.4961 - val_loss: 0.6118 - val_mean_io_u: 0.4949
# Epoch 26/200
# 1/1 [==============================] - 0s 222ms/step - loss: 0.6217 - mean_io_u: 0.4964 - val_loss: 0.6077 - val_mean_io_u: 0.4955
# Epoch 27/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6179 - mean_io_u: 0.4959 - val_loss: 0.6026 - val_mean_io_u: 0.4967
# Epoch 28/200
# 1/1 [==============================] - 0s 318ms/step - loss: 0.6138 - mean_io_u: 0.4957 - val_loss: 0.5990 - val_mean_io_u: 0.4967
# Epoch 29/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6118 - mean_io_u: 0.4948 - val_loss: 0.5953 - val_mean_io_u: 0.4967
# Epoch 30/200
# 1/1 [==============================] - 0s 220ms/step - loss: 0.6084 - mean_io_u: 0.4939 - val_loss: 0.5936 - val_mean_io_u: 0.4955
# Epoch 31/200
# 1/1 [==============================] - 0s 227ms/step - loss: 0.6028 - mean_io_u: 0.4963 - val_loss: 0.5889 - val_mean_io_u: 0.4961
# Epoch 32/200
# 1/1 [==============================] - 0s 247ms/step - loss: 0.6013 - mean_io_u: 0.4955 - val_loss: 0.5844 - val_mean_io_u: 0.4967
# Epoch 33/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.5949 - mean_io_u: 0.4962 - val_loss: 0.5817 - val_mean_io_u: 0.4961
# Epoch 34/200
# 1/1 [==============================] - 0s 358ms/step - loss: 0.5939 - mean_io_u: 0.4955 - val_loss: 0.5768 - val_mean_io_u: 0.4967
# Epoch 35/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.5908 - mean_io_u: 0.4943 - val_loss: 0.5762 - val_mean_io_u: 0.4955
# Epoch 36/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.5875 - mean_io_u: 0.4945 - val_loss: 0.5711 - val_mean_io_u: 0.4961
# Epoch 37/200
# 1/1 [==============================] - 0s 327ms/step - loss: 0.5859 - mean_io_u: 0.4943 - val_loss: 0.5646 - val_mean_io_u: 0.4973
# Epoch 38/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.5787 - mean_io_u: 0.4957 - val_loss: 0.5643 - val_mean_io_u: 0.4961
# Epoch 39/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5821 - mean_io_u: 0.4943 - val_loss: 0.5612 - val_mean_io_u: 0.4961
# Epoch 40/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.5758 - mean_io_u: 0.4954 - val_loss: 0.5598 - val_mean_io_u: 0.4955
# Epoch 41/200
# 1/1 [==============================] - 0s 357ms/step - loss: 0.5697 - mean_io_u: 0.4960 - val_loss: 0.5522 - val_mean_io_u: 0.4967
# Epoch 42/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.5677 - mean_io_u: 0.4954 - val_loss: 0.5507 - val_mean_io_u: 0.4961
# Epoch 43/200
# 1/1 [==============================] - 0s 256ms/step - loss: 0.5631 - mean_io_u: 0.4957 - val_loss: 0.5493 - val_mean_io_u: 0.4955
# Epoch 44/200
# 1/1 [==============================] - 0s 344ms/step - loss: 0.5666 - mean_io_u: 0.4921 - val_loss: 0.5440 - val_mean_io_u: 0.4961
# Epoch 45/200
# 1/1 [==============================] - 0s 186ms/step - loss: 0.5597 - mean_io_u: 0.4945 - val_loss: 0.5429 - val_mean_io_u: 0.4955
# Epoch 46/200
# 1/1 [==============================] - 0s 245ms/step - loss: 0.5509 - mean_io_u: 0.4957 - val_loss: 0.5392 - val_mean_io_u: 0.4955
# Epoch 47/200
# 1/1 [==============================] - 0s 320ms/step - loss: 0.5456 - mean_io_u: 0.4968 - val_loss: 0.5328 - val_mean_io_u: 0.4961
# Epoch 48/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.5485 - mean_io_u: 0.4949 - val_loss: 0.5293 - val_mean_io_u: 0.4961
# Epoch 49/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.5502 - mean_io_u: 0.4934 - val_loss: 0.5287 - val_mean_io_u: 0.4955
# Epoch 50/200
# 1/1 [==============================] - 0s 322ms/step - loss: 0.5349 - mean_io_u: 0.4965 - val_loss: 0.5220 - val_mean_io_u: 0.4961
# Epoch 51/200
# 1/1 [==============================] - 0s 313ms/step - loss: 0.5285 - mean_io_u: 0.4971 - val_loss: 0.5179 - val_mean_io_u: 0.4961
# Epoch 52/200
# 1/1 [==============================] - 0s 194ms/step - loss: 0.5296 - mean_io_u: 0.4964 - val_loss: 0.5202 - val_mean_io_u: 0.4949
# Epoch 53/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.5398 - mean_io_u: 0.4931 - val_loss: 0.5139 - val_mean_io_u: 0.4955
# Epoch 54/200
# 1/1 [==============================] - 0s 256ms/step - loss: 0.5239 - mean_io_u: 0.4953 - val_loss: 0.5101 - val_mean_io_u: 0.4955
# Epoch 55/200
# 1/1 [==============================] - 0s 245ms/step - loss: 0.5200 - mean_io_u: 0.4956 - val_loss: 0.5028 - val_mean_io_u: 0.4961
# Epoch 56/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.5205 - mean_io_u: 0.4939 - val_loss: 0.4990 - val_mean_io_u: 0.4961
# Epoch 57/200
# 1/1 [==============================] - 0s 214ms/step - loss: 0.5143 - mean_io_u: 0.4949 - val_loss: 0.5023 - val_mean_io_u: 0.4949
# Epoch 58/200
# 1/1 [==============================] - 0s 252ms/step - loss: 0.5123 - mean_io_u: 0.4958 - val_loss: 0.4913 - val_mean_io_u: 0.4961
# Epoch 59/200
# 1/1 [==============================] - 0s 345ms/step - loss: 0.5048 - mean_io_u: 0.4961 - val_loss: 0.4834 - val_mean_io_u: 0.4967
# Epoch 60/200
# 1/1 [==============================] - 0s 309ms/step - loss: 0.5047 - mean_io_u: 0.4953 - val_loss: 0.4793 - val_mean_io_u: 0.4967
# Epoch 61/200
# 1/1 [==============================] - 0s 249ms/step - loss: 0.5095 - mean_io_u: 0.4944 - val_loss: 0.4796 - val_mean_io_u: 0.4961
# Epoch 62/200
# 1/1 [==============================] - 0s 303ms/step - loss: 0.5005 - mean_io_u: 0.4955 - val_loss: 0.4757 - val_mean_io_u: 0.4961
# Epoch 63/200
# 1/1 [==============================] - 0s 326ms/step - loss: 0.4948 - mean_io_u: 0.4955 - val_loss: 0.4674 - val_mean_io_u: 0.4967
# Epoch 64/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4919 - mean_io_u: 0.4954 - val_loss: 0.4633 - val_mean_io_u: 0.4967
# Epoch 65/200
# 1/1 [==============================] - 0s 308ms/step - loss: 0.4884 - mean_io_u: 0.4947 - val_loss: 0.4635 - val_mean_io_u: 0.4961
# Epoch 66/200
# 1/1 [==============================] - 0s 248ms/step - loss: 0.4768 - mean_io_u: 0.4964 - val_loss: 0.4637 - val_mean_io_u: 0.4955
# Epoch 67/200
# 1/1 [==============================] - 0s 245ms/step - loss: 0.4775 - mean_io_u: 0.4959 - val_loss: 0.4596 - val_mean_io_u: 0.4955
# Epoch 68/200
# 1/1 [==============================] - 0s 229ms/step - loss: 0.4733 - mean_io_u: 0.4961 - val_loss: 0.4553 - val_mean_io_u: 0.4955
# Epoch 69/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4815 - mean_io_u: 0.4943 - val_loss: 0.4366 - val_mean_io_u: 0.4973
# Epoch 70/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.4629 - mean_io_u: 0.4961 - val_loss: 0.4470 - val_mean_io_u: 0.4955
# Epoch 71/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.4511 - mean_io_u: 0.4965 - val_loss: 0.4370 - val_mean_io_u: 0.4961
# Epoch 72/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.4625 - mean_io_u: 0.4956 - val_loss: 0.4327 - val_mean_io_u: 0.4961
# Epoch 73/200
# 1/1 [==============================] - 0s 347ms/step - loss: 0.4597 - mean_io_u: 0.4943 - val_loss: 0.4227 - val_mean_io_u: 0.4967
# Epoch 74/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.4530 - mean_io_u: 0.4947 - val_loss: 0.4238 - val_mean_io_u: 0.4961
# Epoch 75/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.4435 - mean_io_u: 0.4957 - val_loss: 0.4189 - val_mean_io_u: 0.4961
# Epoch 76/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.4411 - mean_io_u: 0.4951 - val_loss: 0.4141 - val_mean_io_u: 0.4961
# Epoch 77/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.4333 - mean_io_u: 0.4955 - val_loss: 0.4031 - val_mean_io_u: 0.4967
# Epoch 78/200
# 1/1 [==============================] - 0s 350ms/step - loss: 0.4446 - mean_io_u: 0.4943 - val_loss: 0.3985 - val_mean_io_u: 0.4967
# Epoch 79/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.4237 - mean_io_u: 0.4961 - val_loss: 0.3996 - val_mean_io_u: 0.4961
# Epoch 80/200
# 1/1 [==============================] - 0s 312ms/step - loss: 0.4424 - mean_io_u: 0.4933 - val_loss: 0.3952 - val_mean_io_u: 0.4961
# Epoch 81/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.4232 - mean_io_u: 0.4949 - val_loss: 0.3836 - val_mean_io_u: 0.4967
# Epoch 82/200
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3956 - mean_io_u: 0.4969 - val_loss: 0.3708 - val_mean_io_u: 0.4973
# Epoch 83/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.3961 - mean_io_u: 0.4961 - val_loss: 0.3787 - val_mean_io_u: 0.4961
# Epoch 84/200
# 1/1 [==============================] - 0s 356ms/step - loss: 0.4093 - mean_io_u: 0.4954 - val_loss: 0.3665 - val_mean_io_u: 0.4967
# Epoch 85/200
# 1/1 [==============================] - 0s 215ms/step - loss: 0.4030 - mean_io_u: 0.4954 - val_loss: 0.3757 - val_mean_io_u: 0.4955
# Epoch 86/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.3887 - mean_io_u: 0.4961 - val_loss: 0.3628 - val_mean_io_u: 0.4961
# Epoch 87/200
# 1/1 [==============================] - 0s 368ms/step - loss: 0.3706 - mean_io_u: 0.4965 - val_loss: 0.3414 - val_mean_io_u: 0.4973
# Epoch 88/200
# 1/1 [==============================] - 0s 395ms/step - loss: 0.3869 - mean_io_u: 0.4960 - val_loss: 0.3434 - val_mean_io_u: 0.4967
# Epoch 89/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.3767 - mean_io_u: 0.4961 - val_loss: 0.3536 - val_mean_io_u: 0.4955
# Epoch 90/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.4010 - mean_io_u: 0.4942 - val_loss: 0.3408 - val_mean_io_u: 0.4961
# Epoch 91/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.3783 - mean_io_u: 0.4958 - val_loss: 0.3353 - val_mean_io_u: 0.4961
# Epoch 92/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3637 - mean_io_u: 0.4951 - val_loss: 0.3463 - val_mean_io_u: 0.4949
# Epoch 93/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3866 - mean_io_u: 0.4921 - val_loss: 0.3246 - val_mean_io_u: 0.4961
# Epoch 94/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3569 - mean_io_u: 0.4947 - val_loss: 0.3275 - val_mean_io_u: 0.4955
# Epoch 95/200
# 1/1 [==============================] - 0s 223ms/step - loss: 0.3388 - mean_io_u: 0.4954 - val_loss: 0.3303 - val_mean_io_u: 0.4949
# Epoch 96/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.3417 - mean_io_u: 0.4953 - val_loss: 0.3067 - val_mean_io_u: 0.4961
# Epoch 97/200
# 1/1 [==============================] - 0s 351ms/step - loss: 0.3453 - mean_io_u: 0.4960 - val_loss: 0.2830 - val_mean_io_u: 0.4973
# Epoch 98/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.3675 - mean_io_u: 0.4943 - val_loss: 0.2961 - val_mean_io_u: 0.4961
# Epoch 99/200
# 1/1 [==============================] - 0s 303ms/step - loss: 0.3191 - mean_io_u: 0.4961 - val_loss: 0.2900 - val_mean_io_u: 0.4961
# Epoch 100/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.3136 - mean_io_u: 0.4953 - val_loss: 0.2934 - val_mean_io_u: 0.4955
# Epoch 101/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.3191 - mean_io_u: 0.4939 - val_loss: 0.2781 - val_mean_io_u: 0.4961
# Epoch 102/200
# 1/1 [==============================] - 0s 226ms/step - loss: 0.3170 - mean_io_u: 0.4954 - val_loss: 0.2724 - val_mean_io_u: 0.4961
# Epoch 103/200
# 1/1 [==============================] - 0s 354ms/step - loss: 0.3039 - mean_io_u: 0.4950 - val_loss: 0.2665 - val_mean_io_u: 0.4961
# Epoch 104/200
# 1/1 [==============================] - 0s 227ms/step - loss: 0.3246 - mean_io_u: 0.4931 - val_loss: 0.2710 - val_mean_io_u: 0.4955
# Epoch 105/200
# 1/1 [==============================] - 0s 299ms/step - loss: 0.2902 - mean_io_u: 0.4958 - val_loss: 0.2652 - val_mean_io_u: 0.4955
# Epoch 106/200
# 1/1 [==============================] - 0s 316ms/step - loss: 0.3022 - mean_io_u: 0.4945 - val_loss: 0.2395 - val_mean_io_u: 0.4967
# Epoch 107/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.2654 - mean_io_u: 0.4967 - val_loss: 0.2539 - val_mean_io_u: 0.4955
# Epoch 108/200
# 1/1 [==============================] - 0s 220ms/step - loss: 0.2800 - mean_io_u: 0.4953 - val_loss: 0.2380 - val_mean_io_u: 0.4961
# Epoch 109/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.2600 - mean_io_u: 0.4959 - val_loss: 0.2323 - val_mean_io_u: 0.4961
# Epoch 110/200
# 1/1 [==============================] - 0s 229ms/step - loss: 0.2802 - mean_io_u: 0.4944 - val_loss: 0.2480 - val_mean_io_u: 0.4949
# Epoch 111/200
# 1/1 [==============================] - 0s 194ms/step - loss: 0.2744 - mean_io_u: 0.4952 - val_loss: 0.2428 - val_mean_io_u: 0.4949
# Epoch 112/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.2209 - mean_io_u: 0.4962 - val_loss: 0.2160 - val_mean_io_u: 0.4961
# Epoch 113/200
# 1/1 [==============================] - 0s 196ms/step - loss: 0.2597 - mean_io_u: 0.4941 - val_loss: 0.2323 - val_mean_io_u: 0.4949
# Epoch 114/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.2385 - mean_io_u: 0.4957 - val_loss: 0.2055 - val_mean_io_u: 0.4961
# Epoch 115/200
# 1/1 [==============================] - 0s 228ms/step - loss: 0.2153 - mean_io_u: 0.4959 - val_loss: 0.2221 - val_mean_io_u: 0.4949
# Epoch 116/200
# 1/1 [==============================] - 0s 219ms/step - loss: 0.2346 - mean_io_u: 0.4951 - val_loss: 0.1956 - val_mean_io_u: 0.4961
# Epoch 117/200
# 1/1 [==============================] - 0s 313ms/step - loss: 0.2529 - mean_io_u: 0.4955 - val_loss: 0.1800 - val_mean_io_u: 0.4967
# Epoch 118/200
# 1/1 [==============================] - 0s 320ms/step - loss: 0.2419 - mean_io_u: 0.4952 - val_loss: 0.1862 - val_mean_io_u: 0.4961
# Epoch 119/200
# 1/1 [==============================] - 0s 319ms/step - loss: 0.2674 - mean_io_u: 0.4931 - val_loss: 0.1711 - val_mean_io_u: 0.4967
# Epoch 120/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1836 - mean_io_u: 0.4968 - val_loss: 0.1776 - val_mean_io_u: 0.4961
# Epoch 121/200
# 1/1 [==============================] - 0s 352ms/step - loss: 0.2179 - mean_io_u: 0.4939 - val_loss: 0.1624 - val_mean_io_u: 0.4967
# Epoch 122/200
# 1/1 [==============================] - 0s 227ms/step - loss: 0.1954 - mean_io_u: 0.4953 - val_loss: 0.1805 - val_mean_io_u: 0.4955
# Epoch 123/200
# 1/1 [==============================] - 0s 228ms/step - loss: 0.1891 - mean_io_u: 0.4966 - val_loss: 0.1763 - val_mean_io_u: 0.4955
# Epoch 124/200
# 1/1 [==============================] - 0s 390ms/step - loss: 0.2050 - mean_io_u: 0.4956 - val_loss: 0.1392 - val_mean_io_u: 0.4973
# Epoch 125/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.2183 - mean_io_u: 0.4941 - val_loss: 0.1578 - val_mean_io_u: 0.4961
# Epoch 126/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1994 - mean_io_u: 0.4943 - val_loss: 0.1432 - val_mean_io_u: 0.4967
# Epoch 127/200
# 1/1 [==============================] - 0s 241ms/step - loss: 0.1412 - mean_io_u: 0.4969 - val_loss: 0.1511 - val_mean_io_u: 0.4961
# Epoch 128/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1606 - mean_io_u: 0.4961 - val_loss: 0.1477 - val_mean_io_u: 0.4961
# Epoch 129/200
# 1/1 [==============================] - 0s 322ms/step - loss: 0.2265 - mean_io_u: 0.4922 - val_loss: 0.1448 - val_mean_io_u: 0.4961
# Epoch 130/200
# 1/1 [==============================] - 0s 225ms/step - loss: 0.1598 - mean_io_u: 0.4962 - val_loss: 0.1640 - val_mean_io_u: 0.4949
# Epoch 131/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1730 - mean_io_u: 0.4945 - val_loss: 0.1390 - val_mean_io_u: 0.4961
# Epoch 132/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.2111 - mean_io_u: 0.4935 - val_loss: 0.1252 - val_mean_io_u: 0.4967
# Epoch 133/200
# 1/1 [==============================] - 0s 263ms/step - loss: 0.1799 - mean_io_u: 0.4941 - val_loss: 0.1559 - val_mean_io_u: 0.4949
# Epoch 134/200
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1849 - mean_io_u: 0.4948 - val_loss: 0.1201 - val_mean_io_u: 0.4967
# Epoch 135/200
# 1/1 [==============================] - 0s 262ms/step - loss: 0.1810 - mean_io_u: 0.4946 - val_loss: 0.1398 - val_mean_io_u: 0.4955
# Epoch 136/200
# 1/1 [==============================] - 0s 350ms/step - loss: 0.1678 - mean_io_u: 0.4939 - val_loss: 0.1157 - val_mean_io_u: 0.4967
# Epoch 137/200
# 1/1 [==============================] - 0s 228ms/step - loss: 0.1256 - mean_io_u: 0.4967 - val_loss: 0.1245 - val_mean_io_u: 0.4961
# Epoch 138/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.1208 - mean_io_u: 0.4968 - val_loss: 0.1228 - val_mean_io_u: 0.4961
# Epoch 139/200
# 1/1 [==============================] - 0s 318ms/step - loss: 0.1189 - mean_io_u: 0.4968 - val_loss: 0.0990 - val_mean_io_u: 0.4973
# Epoch 140/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1898 - mean_io_u: 0.4942 - val_loss: 0.0972 - val_mean_io_u: 0.4973
# Epoch 141/200
# 1/1 [==============================] - 0s 384ms/step - loss: 0.1230 - mean_io_u: 0.4965 - val_loss: 0.1065 - val_mean_io_u: 0.4967
# Epoch 142/200
# 1/1 [==============================] - 0s 235ms/step - loss: 0.1266 - mean_io_u: 0.4963 - val_loss: 0.1376 - val_mean_io_u: 0.4949
# Epoch 143/200
# 1/1 [==============================] - 0s 318ms/step - loss: 0.1470 - mean_io_u: 0.4955 - val_loss: 0.0925 - val_mean_io_u: 0.4973
# Epoch 144/200
# 1/1 [==============================] - 0s 319ms/step - loss: 0.1604 - mean_io_u: 0.4953 - val_loss: 0.1020 - val_mean_io_u: 0.4967
# Epoch 145/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.1194 - mean_io_u: 0.4959 - val_loss: 0.1115 - val_mean_io_u: 0.4961
# Epoch 146/200
# 1/1 [==============================] - 0s 224ms/step - loss: 0.1625 - mean_io_u: 0.4950 - val_loss: 0.1207 - val_mean_io_u: 0.4955
# Epoch 147/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.1693 - mean_io_u: 0.4931 - val_loss: 0.0980 - val_mean_io_u: 0.4967
# Epoch 148/200
# 1/1 [==============================] - 0s 356ms/step - loss: 0.1621 - mean_io_u: 0.4937 - val_loss: 0.0861 - val_mean_io_u: 0.4973
# Epoch 149/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.1685 - mean_io_u: 0.4934 - val_loss: 0.1172 - val_mean_io_u: 0.4955
# Epoch 150/200
# 1/1 [==============================] - 0s 371ms/step - loss: 0.1123 - mean_io_u: 0.4966 - val_loss: 0.0949 - val_mean_io_u: 0.4967
# Epoch 151/200
# 1/1 [==============================] - 0s 195ms/step - loss: 0.1282 - mean_io_u: 0.4956 - val_loss: 0.1153 - val_mean_io_u: 0.4955
# Epoch 152/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1088 - mean_io_u: 0.4961 - val_loss: 0.0931 - val_mean_io_u: 0.4967
# Epoch 153/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1255 - mean_io_u: 0.4958 - val_loss: 0.1135 - val_mean_io_u: 0.4955
# Epoch 154/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1623 - mean_io_u: 0.4934 - val_loss: 0.1020 - val_mean_io_u: 0.4961
# Epoch 155/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1281 - mean_io_u: 0.4951 - val_loss: 0.1012 - val_mean_io_u: 0.4961
# Epoch 156/200
# 1/1 [==============================] - 0s 218ms/step - loss: 0.0837 - mean_io_u: 0.4970 - val_loss: 0.1113 - val_mean_io_u: 0.4955
# Epoch 157/200
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1381 - mean_io_u: 0.4952 - val_loss: 0.0894 - val_mean_io_u: 0.4967
# Epoch 158/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1177 - mean_io_u: 0.4951 - val_loss: 0.0886 - val_mean_io_u: 0.4967
# Epoch 159/200
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1159 - mean_io_u: 0.4960 - val_loss: 0.0986 - val_mean_io_u: 0.4961
# Epoch 160/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.1467 - mean_io_u: 0.4944 - val_loss: 0.0875 - val_mean_io_u: 0.4967
# Epoch 161/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1259 - mean_io_u: 0.4955 - val_loss: 0.1082 - val_mean_io_u: 0.4955
# Epoch 162/200
# 1/1 [==============================] - 0s 227ms/step - loss: 0.1306 - mean_io_u: 0.4952 - val_loss: 0.1182 - val_mean_io_u: 0.4949
# Epoch 163/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1564 - mean_io_u: 0.4933 - val_loss: 0.0965 - val_mean_io_u: 0.4961
# Epoch 164/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1088 - mean_io_u: 0.4960 - val_loss: 0.0960 - val_mean_io_u: 0.4961
# Epoch 165/200
# 1/1 [==============================] - 0s 327ms/step - loss: 0.1323 - mean_io_u: 0.4945 - val_loss: 0.0957 - val_mean_io_u: 0.4961
# Epoch 166/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1211 - mean_io_u: 0.4947 - val_loss: 0.0848 - val_mean_io_u: 0.4967
# Epoch 167/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0978 - mean_io_u: 0.4961 - val_loss: 0.0844 - val_mean_io_u: 0.4967
# Epoch 168/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1503 - mean_io_u: 0.4942 - val_loss: 0.0945 - val_mean_io_u: 0.4961
# Epoch 169/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.1313 - mean_io_u: 0.4946 - val_loss: 0.0941 - val_mean_io_u: 0.4961
# Epoch 170/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1077 - mean_io_u: 0.4953 - val_loss: 0.0940 - val_mean_io_u: 0.4961
# Epoch 171/200
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0973 - mean_io_u: 0.4963 - val_loss: 0.0725 - val_mean_io_u: 0.4973
# Epoch 172/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1278 - mean_io_u: 0.4949 - val_loss: 0.0934 - val_mean_io_u: 0.4961
# Epoch 173/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.1268 - mean_io_u: 0.4943 - val_loss: 0.0931 - val_mean_io_u: 0.4961
# Epoch 174/200
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0954 - mean_io_u: 0.4961 - val_loss: 0.0823 - val_mean_io_u: 0.4967
# Epoch 175/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.1371 - mean_io_u: 0.4943 - val_loss: 0.0926 - val_mean_io_u: 0.4961
# Epoch 176/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0957 - mean_io_u: 0.4962 - val_loss: 0.1134 - val_mean_io_u: 0.4949
# Epoch 177/200
# 1/1 [==============================] - 0s 324ms/step - loss: 0.1463 - mean_io_u: 0.4928 - val_loss: 0.0816 - val_mean_io_u: 0.4967
# Epoch 178/200
# 1/1 [==============================] - 0s 350ms/step - loss: 0.1160 - mean_io_u: 0.4947 - val_loss: 0.0712 - val_mean_io_u: 0.4973
# Epoch 179/200
# 1/1 [==============================] - 0s 185ms/step - loss: 0.1050 - mean_io_u: 0.4958 - val_loss: 0.1024 - val_mean_io_u: 0.4955
# Epoch 180/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1010 - mean_io_u: 0.4959 - val_loss: 0.1126 - val_mean_io_u: 0.4949
# Epoch 181/200
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0962 - mean_io_u: 0.4957 - val_loss: 0.0811 - val_mean_io_u: 0.4967
# Epoch 182/200
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1032 - mean_io_u: 0.4963 - val_loss: 0.0810 - val_mean_io_u: 0.4967
# Epoch 183/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.1023 - mean_io_u: 0.4951 - val_loss: 0.1017 - val_mean_io_u: 0.4955
# Epoch 184/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0926 - mean_io_u: 0.4961 - val_loss: 0.0807 - val_mean_io_u: 0.4967
# Epoch 185/200
# 1/1 [==============================] - 0s 193ms/step - loss: 0.0919 - mean_io_u: 0.4964 - val_loss: 0.1015 - val_mean_io_u: 0.4955
# Epoch 186/200
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0967 - mean_io_u: 0.4957 - val_loss: 0.0909 - val_mean_io_u: 0.4961
# Epoch 187/200
# 1/1 [==============================] - 0s 230ms/step - loss: 0.1321 - mean_io_u: 0.4941 - val_loss: 0.1012 - val_mean_io_u: 0.4955
# Epoch 188/200
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0815 - mean_io_u: 0.4968 - val_loss: 0.0907 - val_mean_io_u: 0.4961
# Epoch 189/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1028 - mean_io_u: 0.4956 - val_loss: 0.1009 - val_mean_io_u: 0.4955
# Epoch 190/200
# 1/1 [==============================] - 0s 348ms/step - loss: 0.1248 - mean_io_u: 0.4944 - val_loss: 0.0903 - val_mean_io_u: 0.4961
# Epoch 191/200
# 1/1 [==============================] - 0s 313ms/step - loss: 0.1248 - mean_io_u: 0.4944 - val_loss: 0.0796 - val_mean_io_u: 0.4967
# Epoch 192/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1011 - mean_io_u: 0.4955 - val_loss: 0.0902 - val_mean_io_u: 0.4961
# Epoch 193/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.1204 - mean_io_u: 0.4954 - val_loss: 0.0900 - val_mean_io_u: 0.4961
# Epoch 194/200
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1078 - mean_io_u: 0.4958 - val_loss: 0.0899 - val_mean_io_u: 0.4961
# Epoch 195/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1482 - mean_io_u: 0.4930 - val_loss: 0.0897 - val_mean_io_u: 0.4961
# Epoch 196/200
# 1/1 [==============================] - 0s 246ms/step - loss: 0.1213 - mean_io_u: 0.4945 - val_loss: 0.1000 - val_mean_io_u: 0.4955
# Epoch 197/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.1294 - mean_io_u: 0.4941 - val_loss: 0.0895 - val_mean_io_u: 0.4961
# Epoch 198/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.1311 - mean_io_u: 0.4938 - val_loss: 0.0790 - val_mean_io_u: 0.4967
# Epoch 199/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.1003 - mean_io_u: 0.4953 - val_loss: 0.0998 - val_mean_io_u: 0.4955
# Epoch 200/200
# 1/1 [==============================] - 0s 199ms/step - loss: 0.1097 - mean_io_u: 0.4952 - val_loss: 0.0997 - val_mean_io_u: 0.4955

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "y", label="Training loss")
plt.plot(epochs, val_loss, "r", label="Valdation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()


print(history.history.keys())
acc = history.history["mean_io_u"]
val_acc = history.history["val_mean_io_u"]

# acc = history.history["accuracy"]
# val_acc = history.history["val_accuracy"]

plt.plot(epochs, acc, "y", label="Training acc")
plt.plot(epochs, val_acc, "r", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'mean_io_u', 'val_loss', 'val_mean_io_u'])

# %%
# Show the results of the model on the testing set using the validation generator
# Get the next batch from the generator
(batch_x, batch_y) = next(validation_generator)
# Predict the masks
predicted_masks = model.predict(batch_x)
# Threshold the masks
predicted_masks = (predicted_masks > 0.05).astype(np.uint8)
# Show the results
for image, mask, predicted_mask in zip(batch_x, batch_y, predicted_masks):
    plt.imshow(image)
    plt.show()
    plt.imshow(mask)
    plt.show()
    plt.imshow(predicted_mask)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
